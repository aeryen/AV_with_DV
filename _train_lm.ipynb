# %%
import fastai

# %%
from fastai.text import *

# %%
df_test = pd.read_csv('./project/data_new/pan_15_cls/test.csv')
df_test.head()
# Out:
#   label                                              k_doc  \
# 0     Y  Oh, if you only would. I'd just love to have a...
# 1     Y  you walking into my big, empty halls.  I've xc...
# 2     N  Tomorrow comes the great, grand xcrlfx festiva...
# 3     N  Then you think the sea's to blame for xcrlfx e...
# 4     Y  Yes, Tomasso, tell xcrlfx us the secret; we'll...
#
#                                                u_doc
# 0   xcrlfx Is he now? The late Mr. Mulligan was n...
# 1  Then I run, and I run, and I run, xcrlfx till ...
# 2                 But, bless my heart, consider m...
# 3   xcrlfx Is he now? The late Mr. Mulligan was n...
# 4   xcrlfx And ye're aven makin' a bit of an ilip...

# %%
df_train = pd.read_csv('./project/data_new/pan_15_cls/train.csv')
df_train.head()
# Out:
#   label                                              k_doc  \
# 0     Y   My, my, I was forgetting all about xcrlfx the...
# 1     N                                xcrlfx       xcr...
# 2     N  God!  What beauty! xcrlfx  xcrlfx Umm? xcrlfx ...
# 3     N             Sullen night is laughing day-- xcrl...
# 4     Y   xcrlfx  xcrlfx Gimme a shock. Number Two. xcr...
#
#                                                u_doc
# 0  Oh, he's coming, he's xcrlfx coming. I'm going...
# 1   xcrlfx      But speed thy steps, the cold wil...
# 2  But the grub's gittin' low. xcrlfx  xcrlfx The...
# 3   xcrlfx      It turns the night to day, it shi...
# 4   xcrlfx Who'll it be? Ah, it's Fred Nicholls, ...

# %%
df_all = pd.concat([df_train, df_test])
df_all
# Out:
#     label                                              k_doc  \
# 0       Y   My, my, I was forgetting all about xcrlfx the...
# 1       N                                xcrlfx       xcr...
# 2       N  God!  What beauty! xcrlfx  xcrlfx Umm? xcrlfx ...
# 3       N             Sullen night is laughing day-- xcrl...
# 4       Y   xcrlfx  xcrlfx Gimme a shock. Number Two. xcr...
# ..    ...                                                ...
# 495     Y  Hurry, Jack, and fill up the shoes and stockin...
# 496     N  Naisi and his xcrlfx brothers are well pleased...
# 497     Y  Here's health, then, xcrlfx to herself and you...
# 498     Y  you walking into my big, empty halls.  I've xc...
# 499     N  Naisi and his xcrlfx brothers are well pleased...
#
#                                                  u_doc
# 0    Oh, he's coming, he's xcrlfx coming. I'm going...
# 1     xcrlfx      But speed thy steps, the cold wil...
# 2    But the grub's gittin' low. xcrlfx  xcrlfx The...
# ...

# %%
result = pd.concat( [df_all.k_doc, df_all.u_doc] ).unique()
len(result)
# Out:
# 198
